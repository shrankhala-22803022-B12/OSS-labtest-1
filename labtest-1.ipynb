# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from scipy.signal import butter, filtfilt

# %% [markdown]
# ### Part 1

# %%
np.random.seed(0)
vc= np.random.poisson(0, 1440)
noise = np.random.normal(0, 10,1440)
#rows = np.random.rand(0,10,20)
#cols = np.random.rand(0,10,20)
#num = n
ndata = vc + noise

# %%
def lowpass_filter(data, cutoff=0.05, order=3):
    b, a = butter(order, cutoff, btype='low', analog=False)
    return filtfilt(b, a, data)

# %%
freuem


fin=low_pass_filter(vc,)
# Out:
# [[[nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   ...
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]]
#
#  [[nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   ...
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]]
#
#  [[nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   ...
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]]
#
#  ...
#
#  [[nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   ...
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]]
#
#  [[nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   ...
# ...

# %%
mean = np.mean(vehicle_count)
# Out:
# 0.5000285814946044

# %%
plt.plot(ndata)
plt.show()

# %%
def heavy_traffic
# Out:
#   Cell In[84], line 1
#     def heavy_traffic
#                       ^
# SyntaxError: expected '('
